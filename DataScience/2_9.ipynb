# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("submissions_data_train.csv")

# %%
df =df.loc[df["submission_status"]=="wrong"]

# %%
df.head()
# Out:
#     step_id   timestamp submission_status  user_id
# 2     31972  1478852149             wrong    15853
# 4     31976  1434348123             wrong    15853
# 15    32031  1434363465             wrong    15853
# 33    32795  1434520465             wrong    15853
# 38    32812  1434346160             wrong    15853

# %%
df.groupby("step_id").agg({"submission_status":"count"}).sort_values("submission_status")
# Out:
#          submission_status
# step_id
# 32929                   85
# 32175                  342
# 33362                  673
# 33681                  703
# 33482                  707
# 31991                  713
# 32763                  723
# 31988                  725
# 33984                  762
# 33480                  808
# 33890                  811
# 33998                  859
# 33874                  860
# 33676                  879
# 33487                  932
# 33538                  969
# 33686                 1044
# 33413                 1058
# 31986                 1072
# 33536                 1172
# 120745                1238
# 33983                 1239
# 34041                 1243
# 33418                 1273
# 33734                 1392
# 33674                 1443
# 32190                 1860
# 33732                 1865
# 33684                 1873
# 33534                 1881
# ...                    ...
# 32219                 3879
# 32812                 4219
# ...
