# %%
import pandas as pd

# %%
a = pd.DataFrame.from_dict({"a":[1,2,3], "b": ["asd", "dfad", "fdasf"], "c":["fasd", "df", "dfa"]})

# %%
print(a)
print("#"*10)
print("dtypes")
print(a.dtypes)


print("#"*10)
print("columns")
print(a.columns)


print("#"*10)
print("get_dtype_counts")
print(a.get_dtype_counts())


print("#"*10)
print("index")
print(a.index)

print("#"*10)
print("size")
print(a.size)

print("#"*10)
print("shape")
print(a.shape)
print("#"*10)
# Out:
#    a      b     c
# 0  1    asd  fasd
# 1  2   dfad    df
# 2  3  fdasf   dfa
# ##########
# dtypes
# a     int64
# b    object
# c    object
# dtype: object
# ##########
# columns
# Index(['a', 'b', 'c'], dtype='object')
# ##########
# get_dtype_counts
# int64     1
# object    2
# dtype: int64
# ##########
# index
# RangeIndex(start=0, stop=3, step=1)
# ##########
# size
# 9
# ##########
# shape
# (3, 3)
# ##########

# %%
df_titanic = pd.read_csv("titanic.csv")

# %%
df_titanic.head()
print("columns")
print(len(df_titanic.columns))
print("number of rows")
print(len(df_titanic))
print("dtype counts")
print(df_titanic.get_dtype_counts())
# Out:
# columns
# 12
# number of rows
# 891
# dtype counts
# float64    2
# int64      5
# object     5
# dtype: int64

# %%
df_students = pd.read_csv("StudentsPerformance.csv")

# %%
df_students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sum((df_students["lunch"]=="free/reduced")/len(df_students))
# Out:
# 0.35500000000000026

# %%
df_students["lunch"].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
df_students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df_students[(df_students["lunch"]=="standard")]['math score'].describe()
# Out:
# count    645.000000
# mean      70.034109
# std       13.653501
# min       19.000000
# 25%       61.000000
# 50%       69.000000
# 75%       80.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df_students[(df_students["lunch"]=="standard")].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
df_students[(df_students["lunch"]=="free/reduced")].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df_students["lunch"].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df_students[(df_students["lunch"]=="free/reduced")]['math score'].describe()
# Out:
# count    355.000000
# mean      58.921127
# std       15.159956
# min        0.000000
# 25%       49.000000
# 50%       60.000000
# 75%       69.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
(df_students["lunch"]).describe()
# Out:
# count         1000
# unique           2
# top       standard
# freq           645
# Name: lunch, dtype: object

# %%
df_dota = pd.read_csv("dota_hero_stats.csv")

# %%
df_dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df_dota.groupby("legs").count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
df = pd.read_csv("accountancy.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
df.groupby(["Type", "Executor"])["Salary"].mean()
# Out:
# Type  Executor
# A     Loopa        58.000000
#       Pupa        160.833333
# B     Loopa       145.166667
#       Pupa         77.000000
# C     Loopa       154.333333
#       Pupa         74.500000
# D     Loopa       137.714286
#       Pupa        146.500000
# E     Loopa       164.000000
#       Pupa        131.200000
# F     Loopa       238.000000
#       Pupa        136.250000
# Name: Salary, dtype: float64

# %%
df_dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df_dota.groupby(["attack_type", "primary_attr"]).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
df_species = pd.read_csv("algae.csv")

# %%
df_species
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
df_species.index = df_species["species"]

# %%
df_species
# Out:
#                                    species        genus  group   sucrose  \
# species
# Fucus_vesiculosus        Fucus_vesiculosus        Fucus  brown  3.001472
# Saccharina_japonica    Saccharina_japonica   Saccharina  brown  6.731070
# Fucus_serratus              Fucus_serratus        Fucus  brown  3.276870
# Fucus_distichus            Fucus_distichus        Fucus  brown  6.786996
# Cladophora_fracta        Cladophora_fracta   Cladophora  green  3.861470
# Cladophora_compacta    Cladophora_compacta   Cladophora  green  5.712284
# Cladophora_gracilis    Cladophora_gracilis   Cladophora  green  2.452623
# Palmaria_palmata          Palmaria_palmata     Palmaria    red  0.704580
# Saccharina_latissima  Saccharina_latissima   Saccharina  brown  1.636122
# Ascophyllum_nodosum    Ascophyllum_nodosum  Ascophyllum  brown  6.825467
#
#                         alanin   citrate   glucose  oleic_acid
# species
# Fucus_vesiculosus     3.711498  5.004262  2.548459    6.405165
# ...

# %%
df_species.filter(regex = "Fucus_", axis=0)["alanin"].describe()
# Out:
# count    3.000000
# mean     3.566411
# std      3.149943
# min      0.346431
# 25%      2.028965
# 50%      3.711498
# 75%      5.176401
# max      6.641303
# Name: alanin, dtype: float64

# %%
df_species.filter(regex = "Fucus_", axis=0)["alanin"]
# Out:
# species
# Fucus_vesiculosus    3.711498
# Fucus_serratus       0.346431
# Fucus_distichus      6.641303
# Name: alanin, dtype: float64

# %%
df_species.groupby("group").abs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-8592b819a71f> in <module>
# ----> 1 df_species.groupby("group").abs()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...
